# %%
import requests
import pandas as pdb

# %%
offset_ = 1  # размер шага
limit_ = 100  # количество объектов в выдаче
url = (f'https://xn--80az8a.xn--d1aqf.xn--p1ai/%D1%81%D0%B5%D1%80%D0%B2%D0%B8%D1%81%D1%8B/api/kn/object?offset='
       f'{offset_}&limit={limit_}&sortField=devId.devShortCleanNm&sortType=asc&objStatus=0')

# %%
res = requests.get(url)
objects_data = res.json()
objects_list = objects_data.get('data').get('list')
objids = [x.get('objId') for x in objects_list]

# %%
result = []
for i in objids:
    url_obj = f'https://xn--80az8a.xn--d1aqf.xn--p1ai/%D1%81%D0%B5%D1%80%D0%B2%D0%B8%D1%81%D1%8B/api/object/{i}'
    obj = requests.get(url_obj).json().get('data')
    result.append(obj)

# %%
df = pd.json_normalize(result)

# %%
df.head()
# Out:
#       id  hobjId   pdId  region                             address  floorMin  \
# 0  13398   37165  28141      72     г Тюмень, ул Профсоюзная, д. 56         7
# 1  13397   37201  28141      72     г Тюмень, ул Профсоюзная, д. 56         6
# 2  13391   37219  28101      72     г Тюмень, ул Профсоюзная, д. 56         3
# 3  13383   39024  28105      72     г Тюмень, ул Профсоюзная, д. 56         4
# 4  10891    6541  23054      35  г Вологда, ул Медуницинская, д. 11        17
#
#    floorMax  objElemLivingCnt objReady100PercDt wallMaterialShortDesc  ...  \
# 0        10                43        2024-12-31                Другое  ...
# 1        12                65        2024-12-31                Другое  ...
# 2        12                44        2023-12-31                Другое  ...
# 3        20                68        2023-12-31                Другое  ...
# 4        17               225        2023-12-31                Панель  ...
#
#   metro.time metro.isWalk  metro.colors  complexShortNm airQualityIndexValue  \
# 0        NaN          NaN           NaN             NaN                  NaN
# 1        NaN          NaN           NaN             NaN                  NaN
# 2        NaN          NaN           NaN             NaN                  NaN
# 3        NaN          NaN           NaN             NaN                  NaN
# 4        NaN          NaN           NaN             NaN                  NaN
#
#   greenAreaIndexValue developer.bankruptStage.bankruptStageCd  \
# 0                 NaN                                     NaN
# 1                 NaN                                     NaN
# 2                 NaN                                     NaN
# 3                 NaN                                     NaN
# 4                 NaN                                     NaN
#
#   developer.bankruptStage.bankruptStageDesc  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   developer.bankruptStage.bankruptLawUrl  developer.orgBankruptMsgDttm
# 0                                    NaN                           NaN
# 1                                    NaN                           NaN
# 2                                    NaN                           NaN
# 3                                    NaN                           NaN
# 4                                    NaN                           NaN
#
# [5 rows x 110 columns]
