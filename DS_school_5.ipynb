# %%
import pandas as pd
import numpy as np
import requests # for web-download
import io # for web-download
import re # for data processing
pd.options.mode.chained_assignment = None

# %% [markdown]
# ## Задача 1.

# %%
df = pd.read_csv('D:\DS\DS school\Химический анализ родника в Нескучном саду.csv', sep=';')
df
# Out:
#                                Показатель Единица измерений  \
# 0                                      pH        единицы pH
# 1                                   Запах             баллы
# 2                               Цветность           градусы
# 3                               Жёсткость       мг-эквл/дм3
# 4         Аммиак и аммоний-ион (по азоту)            мг/дм3
# 5                        Нитриты (по NO2)            мг/дм3
# 6                        Нитраты (по NO3)            мг/дм3
# 7                             Фосфаты (P)            мг/дм3
# 8                            Хлориды (Cl)            мг/дм3
# 9                          Сульфаты (SO4)            мг/дм3
# 10  Железо (включая хлорное железо) по Fe            мг/дм3
# 11                                  Нефть            мг/дм3
# 12    Общая минерализация (сухой остаток)            мг/дм3
# 13            Окисляемость перманганатная            мг/дм3
#
#     Результат анализа         Норматив
# ...

# %%
df['Результат'] = 0
for i in range(len(df)):
    cond = df['Норматив'][i].split()[1:2][0]
    res = df['Результат анализа'][i]
    try:
        res = float(res)
        if res:
            if cond == 'пределах':
                intl = df['Норматив'][i].split()[2:][0].split('-')
                low = float(intl[0])
                high = float(intl[1])
                if float(res) >= low and float(res) <= high:
                    df['Результат'][i] = 'Норма'
            elif cond == 'более':
                norm = df['Норматив'][i].split()[2:][0].replace(',', '.')
                try:
                    norm = float(norm)
                except:
                    norm = float(norm[-1:])
                if res <= norm:
                    df['Результат'][i] = 'Норма'
                else:
                    df['Результат'][i] = 'Не норма'
            elif cond == 'менее':
                norm = df['Норматив'][i].split()[2:][0].replace(',', '.')
                try:
                    norm = float(norm)
                except:
                    norm = float(norm[-1:])
                if res <= norm:
                    df['Результат'][i] = 'Норма'
                else:
                    df['Результат'][i] = 'Не норма'
    except:
        df['Результат'][i] = 'Не норма'

# %%
df
# Out:
#                                Показатель Единица измерений  \
# 0                                      pH        единицы pH
# 1                                   Запах             баллы
# 2                               Цветность           градусы
# 3                               Жёсткость       мг-эквл/дм3
# 4         Аммиак и аммоний-ион (по азоту)            мг/дм3
# 5                        Нитриты (по NO2)            мг/дм3
# 6                        Нитраты (по NO3)            мг/дм3
# 7                             Фосфаты (P)            мг/дм3
# 8                            Хлориды (Cl)            мг/дм3
# 9                          Сульфаты (SO4)            мг/дм3
# 10  Железо (включая хлорное железо) по Fe            мг/дм3
# 11                                  Нефть            мг/дм3
# 12    Общая минерализация (сухой остаток)            мг/дм3
# 13            Окисляемость перманганатная            мг/дм3
#
#     Результат анализа         Норматив Результат
# ...

# %% [markdown]
# ## Задача 2.

# %%
orange = ['O']
apple = ['A']
fruits = orange * 5 + apple * 4
cnt = 0
x = orange * 3
for i in range(10000):
    res = np.random.choice(fruits, 3, replace = False)
    if sorted(res) == sorted(x):
        cnt += 1
print(cnt/10000)
# Out:
# 0.118

# %%
# вероятность подтвердилась экспериментально на 10 000 экспериментах

# %% [markdown]
# ## Задача 3.

# %%
cnt = 0
for i in range(10000):
    std = ['S']
    not_std = ['N']
    arr = std * 7 + not_std * 3
    if np.random.choice(arr, 1) == 'S':
        arr.remove('S')
        if np.random.choice(arr, 1) == 'N':
            cnt += 1
print(cnt/10000)
# Out:
# 0.2337

# %%
# вероятность подтвердилась экспериментально на 10 000 экспериментах
